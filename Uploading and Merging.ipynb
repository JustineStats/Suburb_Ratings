# %%
######################################## Uploading and Merging #############################################################
import pandas as pd
import numpy as np 

filepath = '/Users/justineleaclement/Documents/Projets /Australia_SubProjet/'

# loading the three files needed in the merge 
df_micro = pd.read_csv(filepath +'Microburbs.csv')
df_abs = pd.read_csv(filepath + 'ABS Scrapes-csv full with geo.csv')
df_crime = pd.read_csv(filepath +'crime_rates.csv')

#The three dataframes 
print('head of micro',df_micro.head())
print('head of abs',df_abs.head())
print('head of crime',df_crime.head())
# Out:
# head of micro                                     _google_import_A  \
# 0  https://nm4.microburbs.com.au/Other-Territorie...
# 1  https://nm4.microburbs.com.au/SA/City-of-Playf...
# 2    https://nm4.microburbs.com.au/NSW/Sydney/Mascot
# 3                                                NaN
# 4  https://nm4.microburbs.com.au/Vic/Melbourne/Al...
#
#                                              __url        suburb_name  \
# 0                                              NaN  Directions Island
# 1                                              NaN     Elizabeth East
# 2                                              NaN             Mascot
# 3  https://nm4.microburbs.com.au/NSW/Sydney/Mascot         Not found.
# 4                                              NaN         Alphington
#
#                   suburb_city              state  \
# 0  Regional Other Territories  Other Territories
# 1            City of Playford                 SA
# 2                      Sydney                NSW
# 3                  Not found.         Not found.
# 4                   Melbourne                Vic
#
#                                     suburb_languages  \
# 0                                         Not found.
# 1  <span class="add-tooltip" data-toggle="tooltip...
# 2                                         Not found.
# 3                                         Not found.
# 4  <span class="add-tooltip" data-toggle="tooltip...
#
#                                      suburb_ancestry   hip_score  \
# 0                                         Not found.  Not found.
# 1  <span class="add-tooltip" data-toggle="tooltip...           6
# 2                                         Not found.  Not found.
# 3                                         Not found.  Not found.
# 4  <span class="add-tooltip" data-toggle="tooltip...           8
#
#   suburb_bicycle_commuters suburb_uni_students  ...  \
# 0            0% of workers                300%  ...
# 1            1% of workers                  1%  ...
# 2               Not found.          Not found.  ...
# 3               Not found.          Not found.  ...
# 4            8% of workers                  7%  ...
#
#                      suburb_nearby_places_of_worship  \
# 0                                         Not found.
# 1  CRC Churches International (802m away) Churche...
# 2                                         Not found.
# 3                                         Not found.
# 4  Catholic Archdiocese of Melbourne (87m away) A...
#
#                              suburb_nearby_libraries  \
# 0                                         Not found.
# 1  City of Playford Library Service (1km away) Le...
# 2                                         Not found.
# 3                                         Not found.
# 4  Libraries Victoria (1km away) Fairfield Librar...
#
#                                  suburb_nearby_clubs  \
# 0                                         Not found.
# 1  Adult Community Education Regional Officers (9...
# 2                                         Not found.
# 3                                         Not found.
# 4  Alphington Bridge Centre (287m away) Latrobe G...
#
#                suburb_nearby_birds_and_poultry_clubs  \
# 0                                         Not found.
# 1  South Australian Homing Pigeon Association Inc...
# 2                                         Not found.
# 3                                         Not found.
# 4     Budgerigar Council of Victoria Inc. (9km away)
#
#     suburb_nearby_aboriginal_and_torres_strait_clubs  \
# 0                                         Not found.
# 1  Aboriginal Elders Village (3km away) Nunkuwarr...
# 2                                         Not found.
# 3                                         Not found.
# 4  Ready Steady Go Kids (4km away) Supacore Compr...
#
#                           suburb_nearby_social_clubs  \
# 0                        Cocos Club (Inc) (9km away)
# 1  Returned & Services League (372m away) Eastern...
# 2                                         Not found.
# 3                                         Not found.
# 4  Returned & Services League (1km away) North Ke...
#
#                              suburb_nearby_car_clubs  \
# 0                                         Not found.
# 1     Hillman Car Club Of South Australia (9km away)
# 2                                         Not found.
# 3                                         Not found.
# 4  Special Vehicle Hiring Association (3km away) ...
#
#                       suburb_nearby_basketball_clubs  \
# 0                                         Not found.
# 1   Golden Grove Recreation & Arts Centre (7km away)
# 2                                         Not found.
# 3                                         Not found.
# 4  Bulleen Templestowe Basketball Club (5km away)...
#
#         suburb_nearby_local_government_organisations  \
# 0                                         Not found.
# 1  Families & Communities, Department for (1km aw...
# 2                                         Not found.
# 3                                         Not found.
# 4  Vicroads (3km away) Wurundjeri Tribe Land Cult...
#
#                  suburb_nearby_halls
# 0                         Not found.
# 1                    YMCA (5km away)
# 2                         Not found.
# 3                         Not found.
# 4  Masonic Temple Ivalda (797m away)
#
# [5 rows x 109 columns]
# head of abs                                     _google_import_B  __url suburb_name  \
# 0  https://abs.gov.au/census/find-census-data/qui...    NaN   Adaminaby
# 1  https://abs.gov.au/census/find-census-data/qui...    NaN      Albury
# 2  https://abs.gov.au/census/find-census-data/qui...    NaN    Alectown
# 3  https://abs.gov.au/census/find-census-data/qui...    NaN      Alpine
# 4  https://abs.gov.au/census/find-census-data/qui...    NaN      Argoon
#
#   suburb_population suburb_median_age suburb_number_of_families  \
# 0               339                52                        74
# 1             4,955                45                     1,236
# 2               151                49                        43
# 3               141                49                        42
# 4        Not found.        Not found.                Not found.
#
#   suburb_number_of_private_dwellings suburb_number_of_people_per_household  \
# 0                                224                                     2
# 1                              2,630                                     2
# 2                                 67                                   2.4
# 3                                 61                                   2.8
# 4                         Not found.                            Not found.
#
#   suburb_financial_median_monthly_mortgage_repayments  \
# 0                                            $1,083
# 1                                            $1,733
# 2                                            $1,257
# 3                                            $3,033
# 4                                         Not found.
#
#   suburb_financial_median_weekly_household_income  ...  \
# 0                                           $954   ...
# 1                                         $1,601   ...
# 2                                         $1,803   ...
# 3                                         $2,291   ...
# 4                                      Not found.  ...
#
#   suburb_financial_one_cars suburb_financial_two_cars  \
# 0                      30.3                      38.6
# 1                      42.1                      34.2
# 2                      31.7                        27
# 3                       6.2                      22.9
# 4                Not found.                Not found.
#
#   suburb_financial_three_plus_cars suburb_financial_no_cars  \
# 0                               22                      9.1
# 1                             11.9                     10.8
# 2                             30.2                      6.3
# 3                             58.3                        0
# 4                       Not found.               Not found.
#
#                                 Geo Point  \
# 0    -36.01193158762528, 148.786320441595
# 1  -36.07369799464406, 146.91346780765934
# 2  -32.91425516102453, 148.26802074020546
# 3  -34.40869358826243, 150.53677066431447
# 4   -34.91797895821861, 145.6572484339588
#
#                                            Geo Shape Official Name State  \
# 0  {"coordinates":[[[148.71675360000006,-36.06054...     New South Wales
# 1  {"coordinates":[[[146.92431042300007,-36.08614...     New South Wales
# 2  {"coordinates":[[[148.19998799900006,-32.96692...     New South Wales
# 3  {"coordinates":[[[150.5122384670001,-34.422367...     New South Wales
# 4  {"coordinates":[[[145.66848513900004,-35.01702...     New South Wales
#
#   Official Name Local Government Area Official Code Suburb  \
# 0               Snowy Monaro Regional                10015
# 1                              Albury                10027
# 2                              Parkes                10029
# 3                       Wingecarribee                10044
# 4                        Murrumbidgee                10081
#
#   Official Name Suburb
# 0            Adaminaby
# 1               Albury
# 2             Alectown
# 3               Alpine
# 4               Argoon
#
# [5 rows x 126 columns]
# head of crime                                     _google_import_A  __url  \
# 0                                               Link    NaN
# 1     https://redsuburbs.com.au/suburbs/aarons-pass/    NaN
# 2      https://redsuburbs.com.au/suburbs/abbotsbury/    NaN
# 3  https://redsuburbs.com.au/suburbs/abbotsford-nsw/    NaN
# 4     https://redsuburbs.com.au/suburbs/abercrombie/    NaN
#
#                                     Suburb_Full_Name        Suburb_Localty  \
# 0                                         Not found.            Not found.
# 1  Crime rate in Aarons Pass, <a href="https://re...  Mid-Western Regional
# 2  Crime rate in Abbotsbury, <a href="https://red...             Fairfield
# 3  Crime rate in Abbotsford (NSW), <a href="https...            Canada Bay
# 4  Crime rate in Abercrombie, <a href="https://re...     Bathurst Regional
#
#            crime_rank suburb_size suburb_total_crimes  \
# 0          Not found.  Not found.          Not found.
# 1  Crime Rank: 10/100   82.76 km2                   2
# 2  Crime Rank: 10/100    4.98 km2                  97
# 3  Crime Rank: 10/100    1.02 km2                 140
# 4  Crime Rank: 10/100    2.98 km2                  32
#
#   suburb_crime_per_1000_people property_crimes violent_crimes_per_1000_people  \
# 0                   Not found.      Not found.                     Not found.
# 1                        60.61               1                           0.00
# 2                        23.10              30                           5.00
# 3                        25.78              47                           3.87
# 4                        28.39               8                           7.10
#
#   percentage_suburbs_with_less_violet_crimes  \
# 0                                 Not found.
# 1                                         0%
# 2                                     68.66%
# 3                                     63.97%
# 4                                     75.35%
#
#   percentage_suburbs_with_less_property_crimes  \
# 0                                   Not found.
# 1                                       78.37%
# 2                                       44.41%
# 3                                        47.4%
# 4                                       44.37%
#
#                                      top_crime_types  \
# 0                                         Not found.
# 1  Top crime types: Property damage In 2022 in Aa...
# 2  Top crime types: Assault and related offences ...
# 3  Top crime types: Deception In 2022 in Abbotsfo...
# 4  Top crime types: Justice procedures offences I...
#
#   changes_of_being_a_victim_of_a_violent_crime_in_suburb  \
# 0                                         Not found.
# 1                                           1 in INF
# 2                                           1 in 200
# 3                                           1 in 259
# 4                                           1 in 141
#
#   chances_of_being_a_victim_of_violent_crime_in_state  \
# 0                                         Not found.
# 1                                            1 in 97
# 2                                            1 in 97
# 3                                            1 in 97
# 4                                            1 in 97
#
#   chances_of_being_a_violent_victim_in_australia  \
# 0                                     Not found.
# 1                                       1 in 105
# 2                                       1 in 105
# 3                                       1 in 105
# 4                                       1 in 105
#
#   chances_of_being_a_property_victim_in_suburb  \
# 0                                   Not found.
# 1                                      1 in 33
# 2                                     1 in 140
# 3                                     1 in 116
# 4                                     1 in 141
#
#   chances_of_being_a_property_victim_in_state  \
# 0                                  Not found.
# 1                                     1 in 44
# 2                                     1 in 44
# 3                                     1 in 44
# 4                                     1 in 44
#
#   chances_of_being_a_property_victim_in_australia
# 0                                      Not found.
# 1                                         1 in 31
# 2                                         1 in 31
# 3                                         1 in 31
# 4                                         1 in 31

# %%
print(df_crime['Suburb_Full_Name'])
# Out:
# 0                                               Not found.
# 1        Crime rate in Aarons Pass, <a href="https://re...
# 2        Crime rate in Abbotsbury, <a href="https://red...
# 3        Crime rate in Abbotsford (NSW), <a href="https...
# 4        Crime rate in Abercrombie, <a href="https://re...
#                                ...
# 13638                                           Not found.
# 13639                                           Not found.
# 13640                                           Not found.
# 13641                                           Not found.
# 13642                                           Not found.
# Name: Suburb_Full_Name, Length: 13643, dtype: object

# %%
"""
0                                               Not found.
1        Crime rate in Aarons Pass, <a href="https://re...
2        Crime rate in Abbotsbury, <a href="https://red...
3        Crime rate in Abbotsford (NSW), <a href="https...
4        Crime rate in Abercrombie, <a href="https://re...
                               ...                        
13638                                           Not found.
13639                                           Not found.
13640                                           Not found.
13641                                           Not found.
13642                                           Not found.

Name: Suburb_Full_Name, Length: 13643, dtype: object"""

print("Changing 'Crime rate in Aarons Pass, <a href=https://re...' to just the name of the suburb 'Aarons Pass'")
# Out:
# Changing 'Crime rate in Aarons Pass, <a href=https://re...' to just the name of the suburb 'Aarons Pass'

# %%
# Cleaning dataframe
# Remove "Crime rate in " from 'Suburb_Full_Name' column + rename subrub name in df_crime to facilitate merging
df_crime['Suburb_Full_Name'] = df_crime['Suburb_Full_Name'].str.replace('Crime rate in ', '')
df_crime.rename(columns={'Suburb_Full_Name': 'suburb_name'}, inplace=True)
# Extracting only the suburb name before the comma #because before the subrub name was 'name, https...'
df_crime['suburb_name'] = df_crime['suburb_name'].str.split(',', expand=True)[0] #0 keep the first string

# displaying the updated 'crime' DataFrame with only suburb names
print(df_crime['suburb_name'])
# Out:
# 0              Not found.
# 1             Aarons Pass
# 2              Abbotsbury
# 3        Abbotsford (NSW)
# 4             Abercrombie
#                ...
# 13638          Not found.
# 13639          Not found.
# 13640          Not found.
# 13641          Not found.
# 13642          Not found.
# Name: suburb_name, Length: 13643, dtype: object

# %%
#MERGING - micro on abs then crime on merged set - abs first as it is the most complete 

# left join of df_abs with df_micro on 'suburb_name'
merged_df = df_abs.merge(df_micro, on='suburb_name', how='left')
# Perform a left join of the above result with df_crime on 'suburb_name'
merged_df = merged_df.merge(df_crime, on='suburb_name', how='left')

# %%
#CHECKING MERGED DATAFRAME

merged_df = merged_df.drop('__url_x', axis=1)
print("Merged LEFT:", merged_df)


#REARRANGING
# reorder columns with 'suburb_name' as the first column for clarity 
first_column = 'suburb_name'
merged_df = merged_df[[first_column] + [col for col in merged_df if col != first_column]]
# drop rows where 'suburb_name' is 'NOT FOUND.' 
# 15 'Not found' # replace not found by nan and remove 
merged_df = merged_df[merged_df['suburb_name'] != 'Not found.']
# Out:
# Merged LEFT:                                          _google_import_B  suburb_name  \
# 0       https://abs.gov.au/census/find-census-data/qui...    Adaminaby
# 1       https://abs.gov.au/census/find-census-data/qui...       Albury
# 2       https://abs.gov.au/census/find-census-data/qui...     Alectown
# 3       https://abs.gov.au/census/find-census-data/qui...       Alpine
# 4       https://abs.gov.au/census/find-census-data/qui...       Argoon
# ...                                                   ...          ...
# 187664  https://abs.gov.au/census/find-census-data/qui...      Millner
# 187665  https://abs.gov.au/census/find-census-data/qui...     Miniyeri
# 187666  https://abs.gov.au/census/find-census-data/qui...       Wadeye
# 187667  https://abs.gov.au/census/find-census-data/qui...  West Arnhem
# 187668  https://abs.gov.au/census/find-census-data/qui...      Hackett
#
#        suburb_population suburb_median_age suburb_number_of_families  \
# 0                    339                52                        74
# 1                  4,955                45                     1,236
# 2                    151                49                        43
# 3                    141                49                        42
# 4             Not found.        Not found.                Not found.
# ...                  ...               ...                       ...
# 187664             2,576                36                       645
# 187665               650                22                       121
# 187666             1,924                27                       408
# 187667               785                27                       173
# 187668             3,227                40                       841
#
#        suburb_number_of_private_dwellings  \
# 0                                     224
# 1                                   2,630
# 2                                      67
# 3                                      61
# 4                              Not found.
# ...                                   ...
# 187664                              1,139
# 187665                                 85
# 187666                                432
# 187667                                217
# 187668                              1,315
#
#        suburb_number_of_people_per_household  \
# 0                                          2
# 1                                          2
# 2                                        2.4
# 3                                        2.8
# 4                                 Not found.
# ...                                      ...
# 187664                                   2.4
# 187665                                   6.1
# 187666                                   4.8
# 187667                                   5.6
# 187668                                   2.6
#
#        suburb_financial_median_monthly_mortgage_repayments  \
# 0                                                 $1,083
# 1                                                 $1,733
# 2                                                 $1,257
# 3                                                 $3,033
# 4                                              Not found.
# ...                                                   ...
# 187664                                            $1,733
# 187665                                                $0
# 187666                                                $0
# 187667                                                $0
# 187668                                            $2,500
#
#        suburb_financial_median_weekly_household_income  \
# 0                                                $954
# 1                                              $1,601
# 2                                              $1,803
# 3                                              $2,291
# 4                                           Not found.
# ...                                                ...
# 187664                                         $1,817
# 187665                                         $1,812
# 187666                                           $767
# 187667                                         $1,174
# 187668                                         $2,623
#
#        suburb_transport_average_car_per_dwelling  ...  \
# 0                                            2.2  ...
# 1                                            1.5  ...
# 2                                            2.2  ...
# 3                                            3.3  ...
# 4                                     Not found.  ...
# ...                                          ...  ...
# 187664                                       1.8  ...
# 187665                                       0.6  ...
# 187666                                       0.6  ...
# 187667                                       0.4  ...
# 187668                                       1.7  ...
#
#        violent_crimes_per_1000_people  \
# 0                               14.75
# 1                               63.98
# 2                               19.87
# 3                                0.00
# 4                                0.00
# ...                               ...
# 187664                            NaN
# 187665                            NaN
# 187666                            NaN
# 187667                            NaN
# 187668                           1.86
#
#        percentage_suburbs_with_less_violet_crimes  \
# 0                                          88.05%
# 1                                          98.03%
# 2                                          91.63%
# 3                                              0%
# 4                                              0%
# ...                                           ...
# 187664                                        NaN
# 187665                                        NaN
# 187666                                        NaN
# 187667                                        NaN
# 187668                                     56.36%
#
#        percentage_suburbs_with_less_property_crimes  \
# 0                                            53.67%
# 1                                            97.47%
# 2                                            67.51%
# 3                                             69.5%
# 4                                                0%
# ...                                             ...
# 187664                                          NaN
# 187665                                          NaN
# 187666                                          NaN
# 187667                                          NaN
# 187668                                       78.77%
#
#                                           top_crime_types  \
# 0       Top crime types: Justice procedures offences I...
# 1       Top crime types: Theft In 2022 in Albury there...
# 2       Top crime types: Assault and related offences ...
# 3       Top crime types: Theft In 2022 in Alpine there...
# 4                                        Top crime types:
# ...                                                   ...
# 187664                                                NaN
# 187665                                                NaN
# 187666                                                NaN
# 187667                                                NaN
# 187668  Top crime types: Theft In 2022 in Hackett ther...
#
#        changes_of_being_a_victim_of_a_violent_crime_in_suburb  \
# 0                                                 1 in 68
# 1                                                 1 in 16
# 2                                                 1 in 50
# 3                                                1 in INF
# 4                                                1 in INF
# ...                                                   ...
# 187664                                                NaN
# 187665                                                NaN
# 187666                                                NaN
# 187667                                                NaN
# 187668                                           1 in 538
#
#        chances_of_being_a_victim_of_violent_crime_in_state  \
# 0                                                 1 in 97
# 1                                                 1 in 97
# 2                                                 1 in 97
# 3                                                 1 in 97
# 4                                                 1 in 97
# ...                                                   ...
# 187664                                                NaN
# 187665                                                NaN
# 187666                                                NaN
# 187667                                                NaN
# 187668                                           1 in 127
#
#        chances_of_being_a_violent_victim_in_australia  \
# 0                                            1 in 105
# 1                                            1 in 105
# 2                                            1 in 105
# 3                                            1 in 105
# 4                                            1 in 105
# ...                                               ...
# 187664                                            NaN
# 187665                                            NaN
# 187666                                            NaN
# 187667                                            NaN
# 187668                                       1 in 105
#
#        chances_of_being_a_property_victim_in_suburb  \
# 0                                           1 in 85
# 1                                            1 in 6
# 2                                           1 in 50
# 3                                           1 in 47
# 4                                          1 in INF
# ...                                             ...
# 187664                                          NaN
# 187665                                          NaN
# 187666                                          NaN
# 187667                                          NaN
# 187668                                      1 in 33
#
#        chances_of_being_a_property_victim_in_state  \
# 0                                          1 in 44
# 1                                          1 in 44
# 2                                          1 in 44
# 3                                          1 in 44
# 4                                          1 in 44
# ...                                            ...
# 187664                                         NaN
# 187665                                         NaN
# 187666                                         NaN
# 187667                                         NaN
# 187668                                     1 in 30
#
#        chances_of_being_a_property_victim_in_australia
# 0                                              1 in 31
# 1                                              1 in 31
# 2                                              1 in 31
# 3                                              1 in 31
# 4                                              1 in 31
# ...                                                ...
# 187664                                             NaN
# 187665                                             NaN
# 187666                                             NaN
# 187667                                             NaN
# 187668                                         1 in 31
#
# [187669 rows x 251 columns]

# %%
unique_suburbs = merged_df['suburb_name'].unique()
print("All unique values present in 'suburb_name':", unique_suburbs)

column_counts = merged_df.count()
print("All non-null values in each columns:", column_counts)

# Number of common 'suburb_name' entries between 'abs' and 'crime'?
common_entries_crime = merged_df['suburb_name'].notnull().sum()
print(f"Common entries between 'abs' and 'crime': {common_entries_crime}")
# Out:
# All unique values present in 'suburb_name': ['Adaminaby' 'Albury' 'Alectown' ... 'Wadeye' 'West Arnhem' 'Hackett']
# All non-null values in each columns: suburb_name                                            15319
# _google_import_B                                       15319
# suburb_population                                      14013
# suburb_median_age                                      14013
# suburb_number_of_families                              14013
#                                                        ...
# chances_of_being_a_victim_of_violent_crime_in_state    13582
# chances_of_being_a_violent_victim_in_australia         13582
# chances_of_being_a_property_victim_in_suburb           13582
# chances_of_being_a_property_victim_in_state            13582
# chances_of_being_a_property_victim_in_australia        13582
# Length: 251, dtype: int64
# Common entries between 'abs' and 'crime': 15319

# %%
# Replacing 'Not found.' with np.nan (which represents a missing or null value);
merged_df = merged_df.apply(lambda x: x.map(lambda y: np.nan if y == 'Not found.' else y))

# Reset the index after removing rows °Important°
merged_df.reset_index(drop=True, inplace=True) 

print(df_abs['suburb_financial_median_monthly_mortgage_repayments'])
print(merged_df['suburb_financial_median_monthly_mortgage_repayments'])
print(merged_df['suburb_financial_median_weekly_rent'])
# Out:
# 0           $1,083
# 1           $1,733
# 2           $1,257
# 3           $3,033
# 4        Not found.
#             ...
# 15329       $1,733
# 15330           $0
# 15331           $0
# 15332           $0
# 15333       $2,500
# Name: suburb_financial_median_monthly_mortgage_repayments, Length: 15334, dtype: object
# 0        $1,083
# 1        $1,733
# 2        $1,257
# 3        $3,033
# 4            NaN
#           ...
# 15314    $1,733
# 15315        $0
# 15316        $0
# 15317        $0
# 15318    $2,500
# Name: suburb_financial_median_monthly_mortgage_repayments, Length: 15319, dtype: object
# 0        $300
# 1        $270
# 2        $160
# 3        $300
# 4          NaN
#          ...
# 15314    $340
# 15315     $70
# 15316     $50
# 15317     $30
# 15318    $374
# Name: suburb_financial_median_weekly_rent, Length: 15319, dtype: object

# %%
#'************** Checking numbers - unique - describe - duplicate ******************'
column_counts = merged_df.count()

print("Column counts:")
print()
print(column_counts)

print('abs:',df_abs['suburb_name'].unique())
print('micro:',df_micro['suburb_name'].unique())
print('crime:',df_crime['suburb_name'].unique())
print('merged:',merged_df['suburb_name'].unique()) 

print('abs:',df_abs['suburb_name'].describe()) #15334
print('micro:',df_micro['suburb_name'].describe()) #6344
print('crime:',df_crime['suburb_name'].describe()) #13616
print('merged:',merged_df['suburb_name'].describe()) # 15319 After removing the 15 ‘Not Found.’

print("15319 is the number of suburbs in Australia, crime rate was only available for 13582 suburbs")
# Out:
# Column counts:
#
# suburb_name                                            15319
# _google_import_B                                       15319
# suburb_population                                      14013
# suburb_median_age                                      14013
# suburb_number_of_families                              14013
#                                                        ...
# chances_of_being_a_victim_of_violent_crime_in_state    13582
# chances_of_being_a_violent_victim_in_australia         13582
# chances_of_being_a_property_victim_in_suburb           13582
# chances_of_being_a_property_victim_in_state            13582
# chances_of_being_a_property_victim_in_australia        13582
# Length: 251, dtype: int64
# abs: ['Adaminaby' 'Albury' 'Alectown' ... 'Wadeye' 'West Arnhem' 'Hackett']
# micro: ['Directions Island' 'Elizabeth East' 'Mascot' ... 'Sellicks Beach'
#  'Daruka' 'Kadina']
# crime: ['Not found.' 'Aarons Pass' 'Abbotsbury' ... 'Whitlam' 'Wright'
#  'Yarralumla']
# merged: ['Adaminaby' 'Albury' 'Alectown' ... 'Wadeye' 'West Arnhem' 'Hackett']
# abs: count          15334
# unique         15320
# top       Not found.
# freq              15
# Name: suburb_name, dtype: object
# micro: count           6344
# unique          4430
# top       Not found.
# freq            1915
# Name: suburb_name, dtype: object
# crime: count          13616
# unique         13611
# top       Not found.
# freq               6
# Name: suburb_name, dtype: object
# merged: count         15319
# unique        15319
# top       Adaminaby
# freq              1
# Name: suburb_name, dtype: object
# 15319 is the number of suburbs in Australia, crime rate was only available for 13582 suburbs

# %%
print("The following is the head of the merged dataframe = merged_df")

print("Display of five surbubs in the merged df:")
print()
print(merged_df.tail())


# Save the merged DataFrame to CSV and JSON files for safety
merged_df.to_csv('merged_inner_df.csv', index=False)
merged_df.to_json('merged_inner_df.json', orient='records', lines=True)

# Check for duplicates in the entire DataFrame
duplicates = merged_df[merged_df.duplicated()]
print("Number of duplicate rows:", len(duplicates))

# Check for duplicates in the 'suburb_name' column
duplicates = merged_df[merged_df.duplicated(subset=['suburb_name'])]
print("Number of duplicate 'suburb_name' rows:", len(duplicates))
# Out:
# The following is the head of the merged dataframe = merged_df
# Display of five surbubs in the merged df:
#
#        suburb_name                                   _google_import_B  \
# 15314      Millner  https://abs.gov.au/census/find-census-data/qui...
# 15315     Miniyeri  https://abs.gov.au/census/find-census-data/qui...
# 15316       Wadeye  https://abs.gov.au/census/find-census-data/qui...
# 15317  West Arnhem  https://abs.gov.au/census/find-census-data/qui...
# 15318      Hackett  https://abs.gov.au/census/find-census-data/qui...
#
#       suburb_population suburb_median_age suburb_number_of_families  \
# 15314             2,576                36                       645
# 15315               650                22                       121
# 15316             1,924                27                       408
# 15317               785                27                       173
# 15318             3,227                40                       841
#
#       suburb_number_of_private_dwellings  \
# 15314                              1,139
# 15315                                 85
# 15316                                432
# 15317                                217
# 15318                              1,315
#
#       suburb_number_of_people_per_household  \
# 15314                                   2.4
# 15315                                   6.1
# 15316                                   4.8
# 15317                                   5.6
# 15318                                   2.6
#
#       suburb_financial_median_monthly_mortgage_repayments  \
# 15314                                            $1,733
# 15315                                                $0
# 15316                                                $0
# 15317                                                $0
# 15318                                            $2,500
#
#       suburb_financial_median_weekly_household_income  \
# 15314                                         $1,817
# 15315                                         $1,812
# 15316                                           $767
# 15317                                         $1,174
# 15318                                         $2,623
#
#       suburb_transport_average_car_per_dwelling  ...  \
# 15314                                       1.8  ...
# 15315                                       0.6  ...
# 15316                                       0.6  ...
# 15317                                       0.4  ...
# 15318                                       1.7  ...
#
#       violent_crimes_per_1000_people  \
# 15314                            NaN
# 15315                            NaN
# 15316                            NaN
# 15317                            NaN
# 15318                           1.86
#
#       percentage_suburbs_with_less_violet_crimes  \
# 15314                                        NaN
# 15315                                        NaN
# 15316                                        NaN
# 15317                                        NaN
# 15318                                     56.36%
#
#       percentage_suburbs_with_less_property_crimes  \
# 15314                                          NaN
# 15315                                          NaN
# 15316                                          NaN
# 15317                                          NaN
# 15318                                       78.77%
#
#                                          top_crime_types  \
# 15314                                                NaN
# 15315                                                NaN
# 15316                                                NaN
# 15317                                                NaN
# 15318  Top crime types: Theft In 2022 in Hackett ther...
#
#       changes_of_being_a_victim_of_a_violent_crime_in_suburb  \
# 15314                                                NaN
# 15315                                                NaN
# 15316                                                NaN
# 15317                                                NaN
# 15318                                           1 in 538
#
#       chances_of_being_a_victim_of_violent_crime_in_state  \
# 15314                                                NaN
# 15315                                                NaN
# 15316                                                NaN
# 15317                                                NaN
# 15318                                           1 in 127
#
#       chances_of_being_a_violent_victim_in_australia  \
# 15314                                            NaN
# 15315                                            NaN
# 15316                                            NaN
# 15317                                            NaN
# 15318                                       1 in 105
#
#       chances_of_being_a_property_victim_in_suburb  \
# 15314                                          NaN
# 15315                                          NaN
# 15316                                          NaN
# 15317                                          NaN
# 15318                                      1 in 33
#
#       chances_of_being_a_property_victim_in_state  \
# 15314                                         NaN
# 15315                                         NaN
# 15316                                         NaN
# 15317                                         NaN
# 15318                                     1 in 30
#
#       chances_of_being_a_property_victim_in_australia
# 15314                                             NaN
# 15315                                             NaN
# 15316                                             NaN
# 15317                                             NaN
# 15318                                         1 in 31
#
# [5 rows x 251 columns]
# Number of duplicate rows: 0
# Number of duplicate 'suburb_name' rows: 0
